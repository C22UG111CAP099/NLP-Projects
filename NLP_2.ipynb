# %%
import pandas as pd #loading data set
import numpy as np # mathematical calculation
import re # Regular Expression used for cleaning the data
import nltk # for basics
import matplotlib.pyplot as plt # visualization
from nltk.corpus import stopwords # to remove be verbs unwanted words
from nltk.tokenize import word_tokenize
from nltk.sentiment import SentimentIntensityAnalyzer
from collections import Counter
from wordcloud import WordCloud

# %%
# library for punctuation for sentiemnet
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Tharu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Tharu\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Tharu\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Tharu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
data={
  "Review":[
    "The food was delicious and the delivery was very quick.",
    "The order arrived late and the food was cold.",
    "Excellent customer service and tasty meals.",
    "The packaging was damaged and food spilled everywhere.",
    "Amazing taste and good portion size.",
    "Poor quality food and terrible dining experience.",
    "Fast delivery and neat packaging.",
    "The burger was undercooked and not fresh.",
    "Great service and friendly staff.",
    "Late delivery and rude customer support.",
    "The pizza was hot and very flavorful.",
    "The order was missing several items.",
    "Fresh ingredients and excellent presentation.",
    "The food was too salty and difficult to eat.",
    "Reasonable prices and good quality meals.",
    "Customer support did not respond to my complaint.",
    "Loved the dessert, it was amazing.",
    "The food arrived cold and soggy.",
    "Quick service and clean packaging.",
    "Very disappointing experience and poor food quality.",
    "The restaurant maintained excellent hygiene standards.",
    "Delivery took more than an hour.",
    "The pasta was perfectly cooked and delicious.",
    "The meal was overpriced for its quality.",
    "Staff were polite and attentive.",
    "Packaging leaked and created a mess.",
    "Best restaurant experience I have had recently.",
    "The chicken was dry and overcooked.",
    "Fast service and fresh food.",
    "The order tracking information was inaccurate.",
    "Excellent taste and affordable prices.",
    "Customer service solved my issue quickly.",
    "The food lacked flavor and seasoning.",
    "Delivery was faster than expected.",
    "Received the wrong order from the restaurant.",
    "Wonderful ambiance and quality food.",
    "The soup was cold when it arrived.",
    "Highly recommend this restaurant to everyone.",
    "Very long waiting time for the order.",
    "Fresh food and attractive packaging.",
    "The restaurant ignored my special instructions.",
    "Outstanding service and delicious meals.",
    "Food portions were too small for the price.",
    "Friendly delivery person and quick service.",
    "The meal tasted stale and unpleasant.",
    "Great value for money and excellent quality.",
    "Poor customer support and delayed response.",
    "The food was fresh, hot, and flavorful.",
    "Terrible experience, I will not order again.",
    "Excellent food quality and prompt delivery."
]

}
df = pd.DataFrame(data)

# %%
print("Restaurant Reviews Dataset")
print(df.head())
# Out:
# Restaurant Reviews Dataset
#                                               Review
# 0  The food was delicious and the delivery was ve...
# 1      The order arrived late and the food was cold.
# 2        Excellent customer service and tasty meals.
# 3  The packaging was damaged and food spilled eve...
# 4               Amazing taste and good portion size.

# %%
stop_words = set(stopwords.words('english'))

def clean_text(text):

  text=text.lower()
  print('lower case',text)
  # remove special charater and number
  text = re.sub(r'[^a-zA-Z\s]','',text)
  print('special character',text)
  #Tokenization
  words = word_tokenize(text)
  print('tokenization')
  # reomve stopwords
  words = [word for word in words if word not in stop_words]
  print('stopwords',words)
  # join words again
  cleaned_text =" ".join(words)

  return cleaned_text

# %%
print(df.columns)
# Out:
# Index(['Review'], dtype='object')

# %%
df['cleaned review'] = df['Review'].apply(clean_text)

print(df[['Review', 'cleaned review']])
# Out:
# lower case the food was delicious and the delivery was very quick.
# special character the food was delicious and the delivery was very quick
# tokenization
# stopwords ['food', 'delicious', 'delivery', 'quick']
# lower case the order arrived late and the food was cold.
# special character the order arrived late and the food was cold
# tokenization
# stopwords ['order', 'arrived', 'late', 'food', 'cold']
# lower case excellent customer service and tasty meals.
# special character excellent customer service and tasty meals
# tokenization
# stopwords ['excellent', 'customer', 'service', 'tasty', 'meals']
# lower case the packaging was damaged and food spilled everywhere.
# special character the packaging was damaged and food spilled everywhere
# tokenization
# stopwords ['packaging', 'damaged', 'food', 'spilled', 'everywhere']
# lower case amazing taste and good portion size.
# special character amazing taste and good portion size
# tokenization
# stopwords ['amazing', 'taste', 'good', 'portion', 'size']
# lower case poor quality food and terrible dining experience.
# special character poor quality food and terrible dining experience
# tokenization
# stopwords ['poor', 'quality', 'food', 'terrible', 'dining', 'experience']
# lower case fast delivery and neat packaging.
# special character fast delivery and neat packaging
# tokenization
# stopwords ['fast', 'delivery', 'neat', 'packaging']
# lower case the burger was undercooked and not fresh.
# special character the burger was undercooked and not fresh
# tokenization
# stopwords ['burger', 'undercooked', 'fresh']
# lower case great service and friendly staff.
# special character great service and friendly staff
# tokenization
# stopwords ['great', 'service', 'friendly', 'staff']
# lower case late delivery and rude customer support.
# special character late delivery and rude customer support
# tokenization
# stopwords ['late', 'delivery', 'rude', 'customer', 'support']
# lower case the pizza was hot and very flavorful.
# special character the pizza was hot and very flavorful
# tokenization
# stopwords ['pizza', 'hot', 'flavorful']
# lower case the order was missing several items.
# special character the order was missing several items
# tokenization
# stopwords ['order', 'missing', 'several', 'items']
# lower case fresh ingredients and excellent presentation.
# special character fresh ingredients and excellent presentation
# tokenization
# stopwords ['fresh', 'ingredients', 'excellent', 'presentation']
# lower case the food was too salty and difficult to eat.
# special character the food was too salty and difficult to eat
# tokenization
# stopwords ['food', 'salty', 'difficult', 'eat']
# lower case reasonable prices and good quality meals.
# special character reasonable prices and good quality meals
# tokenization
# stopwords ['reasonable', 'prices', 'good', 'quality', 'meals']
# lower case customer support did not respond to my complaint.
# special character customer support did not respond to my complaint
# tokenization
# stopwords ['customer', 'support', 'respond', 'complaint']
# lower case loved the dessert, it was amazing.
# special character loved the dessert it was amazing
# tokenization
# stopwords ['loved', 'dessert', 'amazing']
# lower case the food arrived cold and soggy.
# special character the food arrived cold and soggy
# tokenization
# stopwords ['food', 'arrived', 'cold', 'soggy']
# lower case quick service and clean packaging.
# special character quick service and clean packaging
# tokenization
# stopwords ['quick', 'service', 'clean', 'packaging']
# lower case very disappointing experience and poor food quality.
# special character very disappointing experience and poor food quality
# tokenization
# stopwords ['disappointing', 'experience', 'poor', 'food', 'quality']
# lower case the restaurant maintained excellent hygiene standards.
# special character the restaurant maintained excellent hygiene standards
# tokenization
# stopwords ['restaurant', 'maintained', 'excellent', 'hygiene', 'standards']
# lower case delivery took more than an hour.
# special character delivery took more than an hour
# tokenization
# stopwords ['delivery', 'took', 'hour']
# lower case the pasta was perfectly cooked and delicious.
# special character the pasta was perfectly cooked and delicious
# tokenization
# stopwords ['pasta', 'perfectly', 'cooked', 'delicious']
# lower case the meal was overpriced for its quality.
# special character the meal was overpriced for its quality
# tokenization
# stopwords ['meal', 'overpriced', 'quality']
# lower case staff were polite and attentive.
# special character staff were polite and attentive
# tokenization
# stopwords ['staff', 'polite', 'attentive']
# lower case packaging leaked and created a mess.
# special character packaging leaked and created a mess
# tokenization
# stopwords ['packaging', 'leaked', 'created', 'mess']
# lower case best restaurant experience i have had recently.
# special character best restaurant experience i have had recently
# tokenization
# stopwords ['best', 'restaurant', 'experience', 'recently']
# lower case the chicken was dry and overcooked.
# special character the chicken was dry and overcooked
# tokenization
# stopwords ['chicken', 'dry', 'overcooked']
# lower case fast service and fresh food.
# special character fast service and fresh food
# tokenization
# stopwords ['fast', 'service', 'fresh', 'food']
# lower case the order tracking information was inaccurate.
# special character the order tracking information was inaccurate
# tokenization
# stopwords ['order', 'tracking', 'information', 'inaccurate']
# lower case excellent taste and affordable prices.
# special character excellent taste and affordable prices
# tokenization
# stopwords ['excellent', 'taste', 'affordable', 'prices']
# lower case customer service solved my issue quickly.
# special character customer service solved my issue quickly
# tokenization
# stopwords ['customer', 'service', 'solved', 'issue', 'quickly']
# lower case the food lacked flavor and seasoning.
# special character the food lacked flavor and seasoning
# tokenization
# stopwords ['food', 'lacked', 'flavor', 'seasoning']
# lower case delivery was faster than expected.
# special character delivery was faster than expected
# tokenization
# stopwords ['delivery', 'faster', 'expected']
# lower case received the wrong order from the restaurant.
# special character received the wrong order from the restaurant
# tokenization
# stopwords ['received', 'wrong', 'order', 'restaurant']
# lower case wonderful ambiance and quality food.
# special character wonderful ambiance and quality food
# tokenization
# stopwords ['wonderful', 'ambiance', 'quality', 'food']
# lower case the soup was cold when it arrived.
# special character the soup was cold when it arrived
# tokenization
# stopwords ['soup', 'cold', 'arrived']
# lower case highly recommend this restaurant to everyone.
# special character highly recommend this restaurant to everyone
# tokenization
# stopwords ['highly', 'recommend', 'restaurant', 'everyone']
# lower case very long waiting time for the order.
# special character very long waiting time for the order
# tokenization
# stopwords ['long', 'waiting', 'time', 'order']
# lower case fresh food and attractive packaging.
# special character fresh food and attractive packaging
# tokenization
# stopwords ['fresh', 'food', 'attractive', 'packaging']
# lower case the restaurant ignored my special instructions.
# special character the restaurant ignored my special instructions
# tokenization
# stopwords ['restaurant', 'ignored', 'special', 'instructions']
# lower case outstanding service and delicious meals.
# special character outstanding service and delicious meals
# tokenization
# stopwords ['outstanding', 'service', 'delicious', 'meals']
# lower case food portions were too small for the price.
# special character food portions were too small for the price
# tokenization
# stopwords ['food', 'portions', 'small', 'price']
# lower case friendly delivery person and quick service.
# special character friendly delivery person and quick service
# tokenization
# stopwords ['friendly', 'delivery', 'person', 'quick', 'service']
# lower case the meal tasted stale and unpleasant.
# special character the meal tasted stale and unpleasant
# tokenization
# stopwords ['meal', 'tasted', 'stale', 'unpleasant']
# lower case great value for money and excellent quality.
# special character great value for money and excellent quality
# tokenization
# stopwords ['great', 'value', 'money', 'excellent', 'quality']
# lower case poor customer support and delayed response.
# special character poor customer support and delayed response
# tokenization
# stopwords ['poor', 'customer', 'support', 'delayed', 'response']
# lower case the food was fresh, hot, and flavorful.
# special character the food was fresh hot and flavorful
# tokenization
# stopwords ['food', 'fresh', 'hot', 'flavorful']
# lower case terrible experience, i will not order again.
# special character terrible experience i will not order again
# tokenization
# stopwords ['terrible', 'experience', 'order']
# lower case excellent food quality and prompt delivery.
# special character excellent food quality and prompt delivery
# tokenization
# stopwords ['excellent', 'food', 'quality', 'prompt', 'delivery']
#                                                Review  \
# 0   The food was delicious and the delivery was ve...
# 1       The order arrived late and the food was cold.
# 2         Excellent customer service and tasty meals.
# 3   The packaging was damaged and food spilled eve...
# 4                Amazing taste and good portion size.
# 5   Poor quality food and terrible dining experience.
# 6                   Fast delivery and neat packaging.
# 7           The burger was undercooked and not fresh.
# 8                   Great service and friendly staff.
# 9            Late delivery and rude customer support.
# 10              The pizza was hot and very flavorful.
# 11               The order was missing several items.
# 12      Fresh ingredients and excellent presentation.
# 13       The food was too salty and difficult to eat.
# 14          Reasonable prices and good quality meals.
# 15  Customer support did not respond to my complaint.
# 16                 Loved the dessert, it was amazing.
# 17                   The food arrived cold and soggy.
# 18                 Quick service and clean packaging.
# 19  Very disappointing experience and poor food qu...
# 20  The restaurant maintained excellent hygiene st...
# 21                   Delivery took more than an hour.
# 22      The pasta was perfectly cooked and delicious.
# 23           The meal was overpriced for its quality.
# 24                   Staff were polite and attentive.
# 25               Packaging leaked and created a mess.
# 26    Best restaurant experience I have had recently.
# 27                The chicken was dry and overcooked.
# 28                       Fast service and fresh food.
# 29     The order tracking information was inaccurate.
# 30             Excellent taste and affordable prices.
# 31          Customer service solved my issue quickly.
# 32              The food lacked flavor and seasoning.
# 33                 Delivery was faster than expected.
# 34      Received the wrong order from the restaurant.
# 35               Wonderful ambiance and quality food.
# 36                 The soup was cold when it arrived.
# 37      Highly recommend this restaurant to everyone.
# 38              Very long waiting time for the order.
# 39               Fresh food and attractive packaging.
# 40    The restaurant ignored my special instructions.
# 41           Outstanding service and delicious meals.
# 42        Food portions were too small for the price.
# 43        Friendly delivery person and quick service.
# 44              The meal tasted stale and unpleasant.
# 45       Great value for money and excellent quality.
# 46        Poor customer support and delayed response.
# 47            The food was fresh, hot, and flavorful.
# 48       Terrible experience, I will not order again.
# 49        Excellent food quality and prompt delivery.
#
#                                        cleaned review
# 0                       food delicious delivery quick
# 1                        order arrived late food cold
# 2              excellent customer service tasty meals
# 3           packaging damaged food spilled everywhere
# 4                     amazing taste good portion size
# 5        poor quality food terrible dining experience
# 6                        fast delivery neat packaging
# 7                            burger undercooked fresh
# 8                        great service friendly staff
# 9                 late delivery rude customer support
# 10                                pizza hot flavorful
# 11                        order missing several items
# 12           fresh ingredients excellent presentation
# 13                           food salty difficult eat
# 14               reasonable prices good quality meals
# 15                 customer support respond complaint
# 16                              loved dessert amazing
# 17                            food arrived cold soggy
# 18                      quick service clean packaging
# 19         disappointing experience poor food quality
# 20  restaurant maintained excellent hygiene standards
# 21                                 delivery took hour
# 22                   pasta perfectly cooked delicious
# 23                            meal overpriced quality
# 24                             staff polite attentive
# 25                      packaging leaked created mess
# 26                best restaurant experience recently
# 27                             chicken dry overcooked
# 28                            fast service fresh food
# 29              order tracking information inaccurate
# 30                  excellent taste affordable prices
# 31              customer service solved issue quickly
# 32                       food lacked flavor seasoning
# 33                           delivery faster expected
# 34                    received wrong order restaurant
# 35                    wonderful ambiance quality food
# 36                                  soup cold arrived
# 37               highly recommend restaurant everyone
# 38                            long waiting time order
# 39                    fresh food attractive packaging
# 40            restaurant ignored special instructions
# 41                outstanding service delicious meals
# 42                          food portions small price
# 43             friendly delivery person quick service
# 44                       meal tasted stale unpleasant
# 45                great value money excellent quality
# 46             poor customer support delayed response
# 47                           food fresh hot flavorful
# 48                          terrible experience order
# 49             excellent food quality prompt delivery

# %%
print(clean_text(df['cleaned review'].iloc[0]))
# Out:
# lower case food delicious delivery quick
# special character food delicious delivery quick
# tokenization
# stopwords ['food', 'delicious', 'delivery', 'quick']
# food delicious delivery quick

# %%
# sentiment analysis

sia = SentimentIntensityAnalyzer()
def analyzer_sentiment(review):
  score = sia.polarity_scores(review)
  compound = score['compound']
  if compound >= 0.05:
    return "positive"

  elif compound <= -0.05:
    return "negative"
  else:
    return "neutral"

#apply sentiment analysis
df['Sentiment'] = df['cleaned review'].apply(analyzer_sentiment)
print("\nSentiment Analysis")
print(df[['cleaned review','Sentiment']])
# Out:
# Sentiment Analysis
#                                        cleaned review Sentiment
# 0                       food delicious delivery quick  positive
# 1                        order arrived late food cold   neutral
# 2              excellent customer service tasty meals  positive
# 3           packaging damaged food spilled everywhere  negative
# 4                     amazing taste good portion size  positive
# 5        poor quality food terrible dining experience  negative
# 6                        fast delivery neat packaging  positive
# 7                            burger undercooked fresh  positive
# 8                        great service friendly staff  positive
# 9                 late delivery rude customer support  negative
# 10                                pizza hot flavorful   neutral
# 11                        order missing several items  negative
# 12           fresh ingredients excellent presentation  positive
# 13                           food salty difficult eat  negative
# 14               reasonable prices good quality meals  positive
# 15                 customer support respond complaint  positive
# 16                              loved dessert amazing  positive
# 17                            food arrived cold soggy   neutral
# 18                      quick service clean packaging  positive
# 19         disappointing experience poor food quality  negative
# 20  restaurant maintained excellent hygiene standards  positive
# 21                                 delivery took hour   neutral
# 22                   pasta perfectly cooked delicious  positive
# 23                            meal overpriced quality   neutral
# 24                             staff polite attentive   neutral
# 25                      packaging leaked created mess  negative
# 26                best restaurant experience recently  positive
# 27                             chicken dry overcooked   neutral
# 28                            fast service fresh food  positive
# 29              order tracking information inaccurate   neutral
# 30                  excellent taste affordable prices  positive
# 31              customer service solved issue quickly  positive
# 32                       food lacked flavor seasoning   neutral
# 33                           delivery faster expected   neutral
# 34                    received wrong order restaurant  negative
# 35                    wonderful ambiance quality food  positive
# 36                                  soup cold arrived   neutral
# 37               highly recommend restaurant everyone  positive
# 38                            long waiting time order   neutral
# 39                    fresh food attractive packaging  positive
# 40            restaurant ignored special instructions  positive
# 41                outstanding service delicious meals  positive
# 42                          food portions small price   neutral
# 43             friendly delivery person quick service  positive
# 44                       meal tasted stale unpleasant  negative
# 45                great value money excellent quality  positive
# 46             poor customer support delayed response  negative
# 47                           food fresh hot flavorful  positive
# 48                          terrible experience order  negative
# 49             excellent food quality prompt delivery  positive

# %%
all_words=" ".join(df['cleaned review'])
word_list = all_words.split()

#count word frequency

word_freq= Counter(word_list)

#display top 10 keywords
print("\nTop  10 Common Keywords")
print(word_freq.most_common(10))
# Out:
# Top  10 Common Keywords
# [('food', 14), ('delivery', 7), ('service', 7), ('quality', 7), ('order', 6), ('excellent', 6), ('customer', 5), ('packaging', 5), ('fresh', 5), ('restaurant', 5)]

# %%
# identify common complaints
negative_reviews = df[df['Sentiment'] == 'negative'] # Corrected: 'Negative' to 'negative'
negative_words_combined = " ".join(negative_reviews['cleaned review']) # Combine all cleaned negative reviews
negative_word_list = negative_words_combined.split() # Split the combined string into a list of words

# Count word frequency
word_freq_negative = Counter(negative_word_list) # Corrected: 'counter' to 'Counter'

print("\n top 10 negative keywords")
print(word_freq_negative.most_common(10))
# Out:
#  top 10 negative keywords
# [('food', 4), ('poor', 3), ('experience', 3), ('order', 3), ('packaging', 2), ('quality', 2), ('terrible', 2), ('customer', 2), ('support', 2), ('damaged', 1)]

# %%
sentiment_counts = df['Sentiment'].value_counts()
sentiment_counts
# Out:
# Sentiment
# positive    26
# neutral     13
# negative    11
# Name: count, dtype: int64

# %%
sentiment_counts = df["Sentiment"].value_counts()
plt.figure(figsize=(6,5))
plt.bar(sentiment_counts.index,sentiment_counts.values)
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.title("Sentiment Analysis")
plt.show()

# %%
wordcloud = WordCloud(
    width = 800,
    height = 400,
    background_color ='white'
).generate(all_words)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()
